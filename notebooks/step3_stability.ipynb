# %%
from src.preprocessing import get_preprocessed_data
from src.stability import  stability_training, plot_stability_results

# %%
X, prob, predictions, y, _ = get_preprocessed_data()

# %%
stability_training_results = stability_training(
    X, y, fractions=[1/5, 1/5, 1/5, 1/5, 1/5]
)
print(stability_training_results)

plot_stability_results(stability_training_results)
# Out:
# Training on 173797 samples (0.20 fraction)
# Training XGBoost with optimal parameters on 173,797 samples
# Model trained in 5.52 seconds
# Accuracy: 0.6477
# Precision: 0.3310
# Recall: 0.6595
# F1-Score: 0.4408
# ROC-AUC: 0.7094
# Optimal threshold: 0.4645
#
# Training on 347595 samples (0.40 fraction)
# Training XGBoost with optimal parameters on 347,595 samples
# Model trained in 7.31 seconds
# Accuracy: 0.6678
# Precision: 0.3433
# Recall: 0.6338
# F1-Score: 0.4454
# ROC-AUC: 0.7146
# Optimal threshold: 0.4988
#
# Training on 521392 samples (0.60 fraction)
# Training XGBoost with optimal parameters on 521,392 samples
# Model trained in 9.39 seconds
# Accuracy: 0.6735
# Precision: 0.3472
# Recall: 0.6261
# F1-Score: 0.4467
# ROC-AUC: 0.7176
# Optimal threshold: 0.5082
#
# Training on 695190 samples (0.80 fraction)
# Training XGBoost with optimal parameters on 695,190 samples
# Model trained in 11.41 seconds
# Accuracy: 0.6860
# Precision: 0.3555
# Recall: 0.6048
# ...
